# %%
# HCASE Experiments Cherry Picked Scaffolds
#
# Author: Gergely Zahoranszky-Kohalmi, PhD
#
# Email: gergely.zahoranszky-kohalmi@nih.gov
#
# Organization: National Center for Advancing Translational Sciences (NCATS/NIH)
#

# %%
import hcase
import pandas as pd

import matplotlib
#matplotlib.use('agg')
import matplotlib.pyplot as plt
import seaborn as sns

import math

# %%
# Config section



fname_reference_scaffolds = '../data/scaffolds_chembl_24.tab'
fname_structures = '../data/cherrypicked_scaffolds.tab'


fname_out_space = '../data/hc_space.tab'
fname_out_embedding = '../data/cp_scaffolds_hcase_chembl_24_1_bms_dim_2.tab'



fname_out_cp_scaffold_hcase_embedding_plot = '../plots/cp_scaffolds/cp_scaffolds_hcase_chembl_24_1_bms_dim_2.png'
fname_out_colored_embedding = '../data/cp_scaffolds_all_hcase_embedding_coords_chembl_24_1_bms.tab'

n_dim = 2



use_precomputed_reference_space = True

do_downsampling = False
rnd_seed = 55555
sample_size = 200

# %%
# Import datasets

df_ref_scaffolds = pd.read_csv (fname_reference_scaffolds, sep = '\t')
#df_structures = pd.read_csv (fname_structures, sep = '\t')

# %%
# Functions

def cherrypick_scaffolds():




    df = pd.read_csv (fname_out_space, sep = '\t')

    major_markers = [5000, 15000, 16000, 25000, 26000, 35000, 44000, 45000, 55000]

    selection = []
    df_res = pd.DataFrame()
    first = True

    color_idx = 1
    for marker in major_markers:
        selection = []
        for i in range (marker - 50, marker):
            selection.append(i)
        for i in range (marker, marker + 51):
            selection.append(i)
        df_cp = df[df['order'].isin(selection)].copy()
        df_cp['color'] = color_idx
        color_idx += 1
        if first:
            df_res = df_cp
            first = False
        else:
            df_res = df_res.append(df_cp, ignore_index = True)

    df_res = df_res.reset_index (drop = True)

    df_res.to_csv(fname_structures, sep ='\t', index = False)

    return (df_res)




def panel_plot_multi_scaffolds (subfig, df, subfig_label, z):
    #print(df.columns)

    #print(df.head)
    

    # Comment this out if you want image titles.
    #plt.title (title)

    subfig_label += str(z)
    
    tab10_palette = ['#1179B0', '#F58C30', '#74BB5A', '#BC412C', '#795B9A', '#764A0C', '#D37DB5', '#7A7A7A', '#B8C449']

    df_1 = df[df['color'] == 1].copy()
    df_2 = df[df['color'] == 2].copy()
    df_3 = df[df['color'] == 3].copy()
    df_4 = df[df['color'] == 4].copy()
    df_5 = df[df['color'] == 5].copy()
    df_6 = df[df['color'] == 6].copy()
    df_7 = df[df['color'] == 7].copy()
    df_8 = df[df['color'] == 8].copy()
    df_9 = df[df['color'] == 9].copy()


    color_1 = list(df_1['color'])[0] - 1
    color_2 = list(df_2['color'])[0] - 1
    color_3 = list(df_3['color'])[0] - 1
    color_4 = list(df_4['color'])[0] - 1
    color_5 = list(df_5['color'])[0] - 1
    color_6 = list(df_6['color'])[0] - 1
    color_7 = list(df_7['color'])[0] - 1
    color_8 = list(df_8['color'])[0] - 1
    color_9 = list(df_9['color'])[0] - 1
 
    #print("color")
    #print(color_1)




    subfig.scatter(df_1['Dim_1'].values, df_1['Dim_2'].values, c = tab10_palette[color_1], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_2['Dim_1'].values, df_2['Dim_2'].values, c = tab10_palette[color_2], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_3['Dim_1'].values, df_3['Dim_2'].values, c = tab10_palette[color_3], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_4['Dim_1'].values, df_4['Dim_2'].values, c = tab10_palette[color_4], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_5['Dim_1'].values, df_5['Dim_2'].values, c = tab10_palette[color_5], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_6['Dim_1'].values, df_6['Dim_2'].values, c = tab10_palette[color_6], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_7['Dim_1'].values, df_7['Dim_2'].values, c = tab10_palette[color_7], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_8['Dim_1'].values, df_8['Dim_2'].values, c = tab10_palette[color_8], alpha = 0.3, marker = 'o', s = 100)
    subfig.scatter(df_9['Dim_1'].values, df_9['Dim_2'].values, c = tab10_palette[color_9], alpha = 0.3, marker = 'o', s = 100)

    subfig.set_title (subfig_label, fontsize=24)
    subfig.set_xlabel ('Dim 1', fontsize=20)
    subfig.set_ylabel ('Dim 2', fontsize=20)
    

    subfig.set_xlim(left = -1)
    subfig.set_ylim(bottom = -1)    
    subfig.set_xlim(right = int(math.pow(2, z)) - 1 + 5)
    subfig.set_ylim(top = int(math.pow(2, z)) - 1 + 5)


def color_scaffolds (df_coords, df_color):
    df = df_coords.merge(df_color, on = 'id', how = 'inner')
    
    return (df)

# %%
# Cherry-picking scaffolds (not part of main HCASE embedding workflow)

df_structures = cherrypick_scaffolds()

# %%
# Clean-up datasets

df_structures = df_structures.rename (columns = {'scaffold_id': 'id'})

# %%
# Reduce datasets for workflow development (optional)

if do_downsampling:

    df_ref_scaffolds = df_ref_scaffolds.sample (n = sample_size, random_state = rnd_seed)
    df_structures = df_structures.sample (n = sample_size, random_state = rnd_seed)

# %%
# Create ChEMBL Scaffold space

if not use_precomputed_reference_space:
    
    df_hcase_space = hcase.train (df_ref_scaffolds)
    df_hcase_space.to_csv (fname_out_space, sep = '\t', index = False)

else:
    
    df_hcase_space = pd.read_csv (fname_out_space, sep = '\t')

# %%
# Embed structures into HCASE space

print (df_structures.head)
    
df_embedded = hcase.embed (df_hcase_space, df_structures, n_dim)
# Out:
# <bound method NDFrame.head of                                              structure  order  \
# 0                                C1=C(NCc2cccnc2)NCNC1   4950
# 1                                O=C1OCCN=C1NNc1ccccc1   4951
# 2                               O=C1OCOC=C1N=Nc1ccccc1   4952
# 3                                  C1=NCNCN1CCc1ccccc1   4953
# 4                                C1=NCN(CCc2ccccc2)CN1   4954
# ..                                                 ...    ...
# 904  O=S(=O)(N=Cc1ccc(N2CCN(Cc3ccccc3-c3ccccc3)CC2)...  55046
# 905  O=C(NS(=O)(=O)c1ccc(NCC2CCOCC2)cc1)c1ccc(N2CCN...  55047
# 906  O=C1C[C@@H](O[C@H]2CCCCO2)C[C@@H](O[C@H]2CCCCO...  55048
# 907  C(CC[C@H]1CCC2C(CC[C@H]3[C@@H]4CCCC4CC[C@H]23)...  55049
# 908  O=C(Nc1ccc2c(c1)CN[C@H](C(=O)N[C@@H]1CCCc3cccc...  55050
#
#                   id                                       scaffold_key  color
# 0     scaffold.20148  14 2 3 2 0 6 1 1 4 0 0 0 4 4 0 0 0 4 0 0 0 2 0...      1
# 1     scaffold.26725  14 2 3 2 0 6 1 1 4 0 0 1 3 5 0 0 2 3 0 1 0 0 2...      1
# 2     scaffold.25812  14 2 3 2 0 6 1 1 4 0 0 2 2 5 0 0 3 2 0 0 0 1 1...      1
# 3     scaffold.18107  14 2 3 2 0 6 1 1 5 0 0 0 5 3 0 0 0 3 0 0 0 2 0...      1
# 4     scaffold.18141  14 2 3 2 0 6 1 1 5 0 0 0 5 3 0 0 0 3 0 0 0 2 0...      1
# ..               ...                                                ...    ...
# 904  scaffold.508795  49 7 11 7 0 6 5 0 16 0 6 2 8 9 0 1 4 4 0 1 0 0...      9
# 905  scaffold.509714  49 7 11 7 0 6 5 0 16 0 6 2 8 10 0 1 5 4 0 1 0 ...      9
# 906  scaffold.507865  49 8 12 6 0 15 3 0 16 0 0 5 11 11 0 0 6 5 0 2 ...      9
# 907  scaffold.506692  49 8 12 8 0 6 4 0 2 0 0 2 0 2 0 0 2 0 3 0 0 0 ...      9
# 908  scaffold.510412  49 8 12 8 0 6 4 3 6 0 0 0 6 10 0 0 4 6 0 0 0 0...      9
#
# [909 rows x 5 columns]>
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:42] WARNING: Proton(s) added/removed
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Proton(s) added/removed
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:43] WARNING: Omitted undefined stereo
# [20:23:44] WARNING: Omitted undefined stereo
# [20:23:44] WARNING: Proton(s) added/removed
# [20:23:44] WARNING: Proton(s) added/removed
# [20:23:44] WARNING: Proton(s) added/removed
# [20:23:44] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Proton(s) added/removed
# [20:23:45] WARNING: Proton(s) added/removed
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Proton(s) added/removed
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:45] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Proton(s) added/removed
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Omitted undefined stereo
# [20:23:46] WARNING: Proton(s) added/removed
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:47] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:48] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:49] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:50] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:51] WARNING: Proton(s) added/removed; Omitted undefined stereo
# [20:23:51] WARNING: Omitted undefined stereo
# [20:23:51] WARNING: Proton(s) added/removed
# [20:23:51] WARNING: Proton(s) added/removed
# [20:23:51] WARNING: Proton(s) added/removed
# [20:23:51] WARNING: Proton(s) added/removed
# [20:23:52] WARNING: Omitted undefined stereo
# [20:23:52] WARNING: Omitted undefined stereo
# [20:23:52] WARNING: Omitted undefined stereo
# [20:23:52] WARNING: Omitted undefined stereo
# [20:23:52] WARNING: Omitted undefined stereo
# [20:23:53] WARNING: Omitted undefined stereo
# [*] Number of input structures: 909
# [*] Number of structures for which scaffold_key was generated: 909
# [*] Finding closest reference scaffold for structure 1 out of 909 .
# [*] Finding closest reference scaffold for structure 2 out of 909 .
# [*] Finding closest reference scaffold for structure 3 out of 909 .
# [*] Finding closest reference scaffold for structure 4 out of 909 .
# [*] Finding closest reference scaffold for structure 5 out of 909 .
# [*] Finding closest reference scaffold for structure 6 out of 909 .
# [*] Finding closest reference scaffold for structure 7 out of 909 .
# [*] Finding closest reference scaffold for structure 8 out of 909 .
# [*] Finding closest reference scaffold for structure 9 out of 909 .
# [*] Finding closest reference scaffold for structure 10 out of 909 .
# [*] Finding closest reference scaffold for structure 11 out of 909 .
# [*] Finding closest reference scaffold for structure 12 out of 909 .
# [*] Finding closest reference scaffold for structure 13 out of 909 .
# [*] Finding closest reference scaffold for structure 14 out of 909 .
# [*] Finding closest reference scaffold for structure 15 out of 909 .
# [*] Finding closest reference scaffold for structure 16 out of 909 .
# [*] Finding closest reference scaffold for structure 17 out of 909 .
# [*] Finding closest reference scaffold for structure 18 out of 909 .
# [*] Finding closest reference scaffold for structure 19 out of 909 .
# [*] Finding closest reference scaffold for structure 20 out of 909 .
# [*] Finding closest reference scaffold for structure 21 out of 909 .
# [*] Finding closest reference scaffold for structure 22 out of 909 .
# [*] Finding closest reference scaffold for structure 23 out of 909 .
# [*] Finding closest reference scaffold for structure 24 out of 909 .
# [*] Finding closest reference scaffold for structure 25 out of 909 .
# [*] Finding closest reference scaffold for structure 26 out of 909 .
# [*] Finding closest reference scaffold for structure 27 out of 909 .
# [*] Finding closest reference scaffold for structure 28 out of 909 .
# [*] Finding closest reference scaffold for structure 29 out of 909 .
# [*] Finding closest reference scaffold for structure 30 out of 909 .
# [*] Finding closest reference scaffold for structure 31 out of 909 .
# [*] Finding closest reference scaffold for structure 32 out of 909 .
# [*] Finding closest reference scaffold for structure 33 out of 909 .
# [*] Finding closest reference scaffold for structure 34 out of 909 .
# [*] Finding closest reference scaffold for structure 35 out of 909 .
# [*] Finding closest reference scaffold for structure 36 out of 909 .
# [*] Finding closest reference scaffold for structure 37 out of 909 .
# [*] Finding closest reference scaffold for structure 38 out of 909 .
# [*] Finding closest reference scaffold for structure 39 out of 909 .
# [*] Finding closest reference scaffold for structure 40 out of 909 .
# [*] Finding closest reference scaffold for structure 41 out of 909 .
# [*] Finding closest reference scaffold for structure 42 out of 909 .
# [*] Finding closest reference scaffold for structure 43 out of 909 .
# [*] Finding closest reference scaffold for structure 44 out of 909 .
# [*] Finding closest reference scaffold for structure 45 out of 909 .
# [*] Finding closest reference scaffold for structure 46 out of 909 .
# [*] Finding closest reference scaffold for structure 47 out of 909 .
# [*] Finding closest reference scaffold for structure 48 out of 909 .
# [*] Finding closest reference scaffold for structure 49 out of 909 .
# [*] Finding closest reference scaffold for structure 50 out of 909 .
# [*] Finding closest reference scaffold for structure 51 out of 909 .
# [*] Finding closest reference scaffold for structure 52 out of 909 .
# [*] Finding closest reference scaffold for structure 53 out of 909 .
# [*] Finding closest reference scaffold for structure 54 out of 909 .
# [*] Finding closest reference scaffold for structure 55 out of 909 .
# [*] Finding closest reference scaffold for structure 56 out of 909 .
# [*] Finding closest reference scaffold for structure 57 out of 909 .
# [*] Finding closest reference scaffold for structure 58 out of 909 .
# [*] Finding closest reference scaffold for structure 59 out of 909 .
# [*] Finding closest reference scaffold for structure 60 out of 909 .
# [*] Finding closest reference scaffold for structure 61 out of 909 .
# [*] Finding closest reference scaffold for structure 62 out of 909 .
# [*] Finding closest reference scaffold for structure 63 out of 909 .
# [*] Finding closest reference scaffold for structure 64 out of 909 .
# [*] Finding closest reference scaffold for structure 65 out of 909 .
# [*] Finding closest reference scaffold for structure 66 out of 909 .
# [*] Finding closest reference scaffold for structure 67 out of 909 .
# [*] Finding closest reference scaffold for structure 68 out of 909 .
# [*] Finding closest reference scaffold for structure 69 out of 909 .
# [*] Finding closest reference scaffold for structure 70 out of 909 .
# [*] Finding closest reference scaffold for structure 71 out of 909 .
# [*] Finding closest reference scaffold for structure 72 out of 909 .
# [*] Finding closest reference scaffold for structure 73 out of 909 .
# [*] Finding closest reference scaffold for structure 74 out of 909 .
# [*] Finding closest reference scaffold for structure 75 out of 909 .
# [*] Finding closest reference scaffold for structure 76 out of 909 .
# [*] Finding closest reference scaffold for structure 77 out of 909 .
# [*] Finding closest reference scaffold for structure 78 out of 909 .
# [*] Finding closest reference scaffold for structure 79 out of 909 .
# [*] Finding closest reference scaffold for structure 80 out of 909 .
# [*] Finding closest reference scaffold for structure 81 out of 909 .
# [*] Finding closest reference scaffold for structure 82 out of 909 .
# [*] Finding closest reference scaffold for structure 83 out of 909 .
# [*] Finding closest reference scaffold for structure 84 out of 909 .
# [*] Finding closest reference scaffold for structure 85 out of 909 .
# [*] Finding closest reference scaffold for structure 86 out of 909 .
# [*] Finding closest reference scaffold for structure 87 out of 909 .
# [*] Finding closest reference scaffold for structure 88 out of 909 .
# [*] Finding closest reference scaffold for structure 89 out of 909 .
# [*] Finding closest reference scaffold for structure 90 out of 909 .
# [*] Finding closest reference scaffold for structure 91 out of 909 .
# [*] Finding closest reference scaffold for structure 92 out of 909 .
# [*] Finding closest reference scaffold for structure 93 out of 909 .
# [*] Finding closest reference scaffold for structure 94 out of 909 .
# [*] Finding closest reference scaffold for structure 95 out of 909 .
# [*] Finding closest reference scaffold for structure 96 out of 909 .
# [*] Finding closest reference scaffold for structure 97 out of 909 .
# [*] Finding closest reference scaffold for structure 98 out of 909 .
# [*] Finding closest reference scaffold for structure 99 out of 909 .
# [*] Finding closest reference scaffold for structure 100 out of 909 .
# [*] Finding closest reference scaffold for structure 101 out of 909 .
# [*] Finding closest reference scaffold for structure 102 out of 909 .
# [*] Finding closest reference scaffold for structure 103 out of 909 .
# [*] Finding closest reference scaffold for structure 104 out of 909 .
# [*] Finding closest reference scaffold for structure 105 out of 909 .
# [*] Finding closest reference scaffold for structure 106 out of 909 .
# [*] Finding closest reference scaffold for structure 107 out of 909 .
# [*] Finding closest reference scaffold for structure 108 out of 909 .
# [*] Finding closest reference scaffold for structure 109 out of 909 .
# [*] Finding closest reference scaffold for structure 110 out of 909 .
# [*] Finding closest reference scaffold for structure 111 out of 909 .
# [*] Finding closest reference scaffold for structure 112 out of 909 .
# [*] Finding closest reference scaffold for structure 113 out of 909 .
# [*] Finding closest reference scaffold for structure 114 out of 909 .
# [*] Finding closest reference scaffold for structure 115 out of 909 .
# [*] Finding closest reference scaffold for structure 116 out of 909 .
# [*] Finding closest reference scaffold for structure 117 out of 909 .
# [*] Finding closest reference scaffold for structure 118 out of 909 .
# [*] Finding closest reference scaffold for structure 119 out of 909 .
# [*] Finding closest reference scaffold for structure 120 out of 909 .
# [*] Finding closest reference scaffold for structure 121 out of 909 .
# [*] Finding closest reference scaffold for structure 122 out of 909 .
# [*] Finding closest reference scaffold for structure 123 out of 909 .
# [*] Finding closest reference scaffold for structure 124 out of 909 .
# [*] Finding closest reference scaffold for structure 125 out of 909 .
# [*] Finding closest reference scaffold for structure 126 out of 909 .
# [*] Finding closest reference scaffold for structure 127 out of 909 .
# [*] Finding closest reference scaffold for structure 128 out of 909 .
# [*] Finding closest reference scaffold for structure 129 out of 909 .
# [*] Finding closest reference scaffold for structure 130 out of 909 .
# [*] Finding closest reference scaffold for structure 131 out of 909 .
# [*] Finding closest reference scaffold for structure 132 out of 909 .
# [*] Finding closest reference scaffold for structure 133 out of 909 .
# [*] Finding closest reference scaffold for structure 134 out of 909 .
# [*] Finding closest reference scaffold for structure 135 out of 909 .
# [*] Finding closest reference scaffold for structure 136 out of 909 .
# [*] Finding closest reference scaffold for structure 137 out of 909 .
# [*] Finding closest reference scaffold for structure 138 out of 909 .
# [*] Finding closest reference scaffold for structure 139 out of 909 .
# [*] Finding closest reference scaffold for structure 140 out of 909 .
# [*] Finding closest reference scaffold for structure 141 out of 909 .
# [*] Finding closest reference scaffold for structure 142 out of 909 .
# [*] Finding closest reference scaffold for structure 143 out of 909 .
# [*] Finding closest reference scaffold for structure 144 out of 909 .
# [*] Finding closest reference scaffold for structure 145 out of 909 .
# [*] Finding closest reference scaffold for structure 146 out of 909 .
# [*] Finding closest reference scaffold for structure 147 out of 909 .
# [*] Finding closest reference scaffold for structure 148 out of 909 .
# [*] Finding closest reference scaffold for structure 149 out of 909 .
# [*] Finding closest reference scaffold for structure 150 out of 909 .
# [*] Finding closest reference scaffold for structure 151 out of 909 .
# [*] Finding closest reference scaffold for structure 152 out of 909 .
# [*] Finding closest reference scaffold for structure 153 out of 909 .
# [*] Finding closest reference scaffold for structure 154 out of 909 .
# [*] Finding closest reference scaffold for structure 155 out of 909 .
# [*] Finding closest reference scaffold for structure 156 out of 909 .
# [*] Finding closest reference scaffold for structure 157 out of 909 .
# [*] Finding closest reference scaffold for structure 158 out of 909 .
# [*] Finding closest reference scaffold for structure 159 out of 909 .
# [*] Finding closest reference scaffold for structure 160 out of 909 .
# [*] Finding closest reference scaffold for structure 161 out of 909 .
# [*] Finding closest reference scaffold for structure 162 out of 909 .
# [*] Finding closest reference scaffold for structure 163 out of 909 .
# [*] Finding closest reference scaffold for structure 164 out of 909 .
# [*] Finding closest reference scaffold for structure 165 out of 909 .
# [*] Finding closest reference scaffold for structure 166 out of 909 .
# [*] Finding closest reference scaffold for structure 167 out of 909 .
# [*] Finding closest reference scaffold for structure 168 out of 909 .
# [*] Finding closest reference scaffold for structure 169 out of 909 .
# [*] Finding closest reference scaffold for structure 170 out of 909 .
# [*] Finding closest reference scaffold for structure 171 out of 909 .
# [*] Finding closest reference scaffold for structure 172 out of 909 .
# [*] Finding closest reference scaffold for structure 173 out of 909 .
# [*] Finding closest reference scaffold for structure 174 out of 909 .
# [*] Finding closest reference scaffold for structure 175 out of 909 .
# [*] Finding closest reference scaffold for structure 176 out of 909 .
# [*] Finding closest reference scaffold for structure 177 out of 909 .
# [*] Finding closest reference scaffold for structure 178 out of 909 .
# [*] Finding closest reference scaffold for structure 179 out of 909 .
# [*] Finding closest reference scaffold for structure 180 out of 909 .
# [*] Finding closest reference scaffold for structure 181 out of 909 .
# [*] Finding closest reference scaffold for structure 182 out of 909 .
# [*] Finding closest reference scaffold for structure 183 out of 909 .
# [*] Finding closest reference scaffold for structure 184 out of 909 .
# [*] Finding closest reference scaffold for structure 185 out of 909 .
# [*] Finding closest reference scaffold for structure 186 out of 909 .
# [*] Finding closest reference scaffold for structure 187 out of 909 .
# [*] Finding closest reference scaffold for structure 188 out of 909 .
# [*] Finding closest reference scaffold for structure 189 out of 909 .
# [*] Finding closest reference scaffold for structure 190 out of 909 .
# [*] Finding closest reference scaffold for structure 191 out of 909 .
# [*] Finding closest reference scaffold for structure 192 out of 909 .
# [*] Finding closest reference scaffold for structure 193 out of 909 .
# [*] Finding closest reference scaffold for structure 194 out of 909 .
# [*] Finding closest reference scaffold for structure 195 out of 909 .
# [*] Finding closest reference scaffold for structure 196 out of 909 .
# [*] Finding closest reference scaffold for structure 197 out of 909 .
# [*] Finding closest reference scaffold for structure 198 out of 909 .
# [*] Finding closest reference scaffold for structure 199 out of 909 .
# [*] Finding closest reference scaffold for structure 200 out of 909 .
# [*] Finding closest reference scaffold for structure 201 out of 909 .
# [*] Finding closest reference scaffold for structure 202 out of 909 .
# [*] Finding closest reference scaffold for structure 203 out of 909 .
# [*] Finding closest reference scaffold for structure 204 out of 909 .
# [*] Finding closest reference scaffold for structure 205 out of 909 .
# [*] Finding closest reference scaffold for structure 206 out of 909 .
# [*] Finding closest reference scaffold for structure 207 out of 909 .
# [*] Finding closest reference scaffold for structure 208 out of 909 .
# [*] Finding closest reference scaffold for structure 209 out of 909 .
# [*] Finding closest reference scaffold for structure 210 out of 909 .
# [*] Finding closest reference scaffold for structure 211 out of 909 .
# [*] Finding closest reference scaffold for structure 212 out of 909 .
# [*] Finding closest reference scaffold for structure 213 out of 909 .
# [*] Finding closest reference scaffold for structure 214 out of 909 .
# [*] Finding closest reference scaffold for structure 215 out of 909 .
# [*] Finding closest reference scaffold for structure 216 out of 909 .
# [*] Finding closest reference scaffold for structure 217 out of 909 .
# [*] Finding closest reference scaffold for structure 218 out of 909 .
# [*] Finding closest reference scaffold for structure 219 out of 909 .
# [*] Finding closest reference scaffold for structure 220 out of 909 .
# [*] Finding closest reference scaffold for structure 221 out of 909 .
# [*] Finding closest reference scaffold for structure 222 out of 909 .
# [*] Finding closest reference scaffold for structure 223 out of 909 .
# [*] Finding closest reference scaffold for structure 224 out of 909 .
# [*] Finding closest reference scaffold for structure 225 out of 909 .
# [*] Finding closest reference scaffold for structure 226 out of 909 .
# [*] Finding closest reference scaffold for structure 227 out of 909 .
# [*] Finding closest reference scaffold for structure 228 out of 909 .
# [*] Finding closest reference scaffold for structure 229 out of 909 .
# [*] Finding closest reference scaffold for structure 230 out of 909 .
# [*] Finding closest reference scaffold for structure 231 out of 909 .
# [*] Finding closest reference scaffold for structure 232 out of 909 .
# [*] Finding closest reference scaffold for structure 233 out of 909 .
# [*] Finding closest reference scaffold for structure 234 out of 909 .
# [*] Finding closest reference scaffold for structure 235 out of 909 .
# [*] Finding closest reference scaffold for structure 236 out of 909 .
# [*] Finding closest reference scaffold for structure 237 out of 909 .
# [*] Finding closest reference scaffold for structure 238 out of 909 .
# [*] Finding closest reference scaffold for structure 239 out of 909 .
# [*] Finding closest reference scaffold for structure 240 out of 909 .
# [*] Finding closest reference scaffold for structure 241 out of 909 .
# [*] Finding closest reference scaffold for structure 242 out of 909 .
# [*] Finding closest reference scaffold for structure 243 out of 909 .
# [*] Finding closest reference scaffold for structure 244 out of 909 .
# [*] Finding closest reference scaffold for structure 245 out of 909 .
# [*] Finding closest reference scaffold for structure 246 out of 909 .
# [*] Finding closest reference scaffold for structure 247 out of 909 .
# [*] Finding closest reference scaffold for structure 248 out of 909 .
# [*] Finding closest reference scaffold for structure 249 out of 909 .
# [*] Finding closest reference scaffold for structure 250 out of 909 .
# [*] Finding closest reference scaffold for structure 251 out of 909 .
# [*] Finding closest reference scaffold for structure 252 out of 909 .
# [*] Finding closest reference scaffold for structure 253 out of 909 .
# [*] Finding closest reference scaffold for structure 254 out of 909 .
# [*] Finding closest reference scaffold for structure 255 out of 909 .
# [*] Finding closest reference scaffold for structure 256 out of 909 .
# [*] Finding closest reference scaffold for structure 257 out of 909 .
# [*] Finding closest reference scaffold for structure 258 out of 909 .
# [*] Finding closest reference scaffold for structure 259 out of 909 .
# [*] Finding closest reference scaffold for structure 260 out of 909 .
# [*] Finding closest reference scaffold for structure 261 out of 909 .
# [*] Finding closest reference scaffold for structure 262 out of 909 .
# [*] Finding closest reference scaffold for structure 263 out of 909 .
# [*] Finding closest reference scaffold for structure 264 out of 909 .
# [*] Finding closest reference scaffold for structure 265 out of 909 .
# [*] Finding closest reference scaffold for structure 266 out of 909 .
# [*] Finding closest reference scaffold for structure 267 out of 909 .
# [*] Finding closest reference scaffold for structure 268 out of 909 .
# [*] Finding closest reference scaffold for structure 269 out of 909 .
# [*] Finding closest reference scaffold for structure 270 out of 909 .
# [*] Finding closest reference scaffold for structure 271 out of 909 .
# [*] Finding closest reference scaffold for structure 272 out of 909 .
# [*] Finding closest reference scaffold for structure 273 out of 909 .
# [*] Finding closest reference scaffold for structure 274 out of 909 .
# [*] Finding closest reference scaffold for structure 275 out of 909 .
# [*] Finding closest reference scaffold for structure 276 out of 909 .
# [*] Finding closest reference scaffold for structure 277 out of 909 .
# [*] Finding closest reference scaffold for structure 278 out of 909 .
# [*] Finding closest reference scaffold for structure 279 out of 909 .
# [*] Finding closest reference scaffold for structure 280 out of 909 .
# [*] Finding closest reference scaffold for structure 281 out of 909 .
# [*] Finding closest reference scaffold for structure 282 out of 909 .
# [*] Finding closest reference scaffold for structure 283 out of 909 .
# [*] Finding closest reference scaffold for structure 284 out of 909 .
# [*] Finding closest reference scaffold for structure 285 out of 909 .
# [*] Finding closest reference scaffold for structure 286 out of 909 .
# [*] Finding closest reference scaffold for structure 287 out of 909 .
# [*] Finding closest reference scaffold for structure 288 out of 909 .
# [*] Finding closest reference scaffold for structure 289 out of 909 .
# [*] Finding closest reference scaffold for structure 290 out of 909 .
# [*] Finding closest reference scaffold for structure 291 out of 909 .
# [*] Finding closest reference scaffold for structure 292 out of 909 .
# [*] Finding closest reference scaffold for structure 293 out of 909 .
# [*] Finding closest reference scaffold for structure 294 out of 909 .
# [*] Finding closest reference scaffold for structure 295 out of 909 .
# [*] Finding closest reference scaffold for structure 296 out of 909 .
# [*] Finding closest reference scaffold for structure 297 out of 909 .
# [*] Finding closest reference scaffold for structure 298 out of 909 .
# [*] Finding closest reference scaffold for structure 299 out of 909 .
# [*] Finding closest reference scaffold for structure 300 out of 909 .
# [*] Finding closest reference scaffold for structure 301 out of 909 .
# [*] Finding closest reference scaffold for structure 302 out of 909 .
# [*] Finding closest reference scaffold for structure 303 out of 909 .
# [*] Finding closest reference scaffold for structure 304 out of 909 .
# [*] Finding closest reference scaffold for structure 305 out of 909 .
# [*] Finding closest reference scaffold for structure 306 out of 909 .
# [*] Finding closest reference scaffold for structure 307 out of 909 .
# [*] Finding closest reference scaffold for structure 308 out of 909 .
# [*] Finding closest reference scaffold for structure 309 out of 909 .
# [*] Finding closest reference scaffold for structure 310 out of 909 .
# [*] Finding closest reference scaffold for structure 311 out of 909 .
# [*] Finding closest reference scaffold for structure 312 out of 909 .
# [*] Finding closest reference scaffold for structure 313 out of 909 .
# [*] Finding closest reference scaffold for structure 314 out of 909 .
# [*] Finding closest reference scaffold for structure 315 out of 909 .
# [*] Finding closest reference scaffold for structure 316 out of 909 .
# [*] Finding closest reference scaffold for structure 317 out of 909 .
# [*] Finding closest reference scaffold for structure 318 out of 909 .
# [*] Finding closest reference scaffold for structure 319 out of 909 .
# [*] Finding closest reference scaffold for structure 320 out of 909 .
# [*] Finding closest reference scaffold for structure 321 out of 909 .
# [*] Finding closest reference scaffold for structure 322 out of 909 .
# [*] Finding closest reference scaffold for structure 323 out of 909 .
# [*] Finding closest reference scaffold for structure 324 out of 909 .
# [*] Finding closest reference scaffold for structure 325 out of 909 .
# [*] Finding closest reference scaffold for structure 326 out of 909 .
# [*] Finding closest reference scaffold for structure 327 out of 909 .
# [*] Finding closest reference scaffold for structure 328 out of 909 .
# [*] Finding closest reference scaffold for structure 329 out of 909 .
# [*] Finding closest reference scaffold for structure 330 out of 909 .
# [*] Finding closest reference scaffold for structure 331 out of 909 .
# [*] Finding closest reference scaffold for structure 332 out of 909 .
# [*] Finding closest reference scaffold for structure 333 out of 909 .
# [*] Finding closest reference scaffold for structure 334 out of 909 .
# [*] Finding closest reference scaffold for structure 335 out of 909 .
# [*] Finding closest reference scaffold for structure 336 out of 909 .
# [*] Finding closest reference scaffold for structure 337 out of 909 .
# [*] Finding closest reference scaffold for structure 338 out of 909 .
# [*] Finding closest reference scaffold for structure 339 out of 909 .
# [*] Finding closest reference scaffold for structure 340 out of 909 .
# [*] Finding closest reference scaffold for structure 341 out of 909 .
# [*] Finding closest reference scaffold for structure 342 out of 909 .
# [*] Finding closest reference scaffold for structure 343 out of 909 .
# [*] Finding closest reference scaffold for structure 344 out of 909 .
# [*] Finding closest reference scaffold for structure 345 out of 909 .
# [*] Finding closest reference scaffold for structure 346 out of 909 .
# [*] Finding closest reference scaffold for structure 347 out of 909 .
# [*] Finding closest reference scaffold for structure 348 out of 909 .
# [*] Finding closest reference scaffold for structure 349 out of 909 .
# [*] Finding closest reference scaffold for structure 350 out of 909 .
# [*] Finding closest reference scaffold for structure 351 out of 909 .
# [*] Finding closest reference scaffold for structure 352 out of 909 .
# [*] Finding closest reference scaffold for structure 353 out of 909 .
# [*] Finding closest reference scaffold for structure 354 out of 909 .
# [*] Finding closest reference scaffold for structure 355 out of 909 .
# [*] Finding closest reference scaffold for structure 356 out of 909 .
# [*] Finding closest reference scaffold for structure 357 out of 909 .
# [*] Finding closest reference scaffold for structure 358 out of 909 .
# [*] Finding closest reference scaffold for structure 359 out of 909 .
# [*] Finding closest reference scaffold for structure 360 out of 909 .
# [*] Finding closest reference scaffold for structure 361 out of 909 .
# [*] Finding closest reference scaffold for structure 362 out of 909 .
# [*] Finding closest reference scaffold for structure 363 out of 909 .
# [*] Finding closest reference scaffold for structure 364 out of 909 .
# [*] Finding closest reference scaffold for structure 365 out of 909 .
# [*] Finding closest reference scaffold for structure 366 out of 909 .
# [*] Finding closest reference scaffold for structure 367 out of 909 .
# [*] Finding closest reference scaffold for structure 368 out of 909 .
# [*] Finding closest reference scaffold for structure 369 out of 909 .
# [*] Finding closest reference scaffold for structure 370 out of 909 .
# [*] Finding closest reference scaffold for structure 371 out of 909 .
# [*] Finding closest reference scaffold for structure 372 out of 909 .
# [*] Finding closest reference scaffold for structure 373 out of 909 .
# [*] Finding closest reference scaffold for structure 374 out of 909 .
# [*] Finding closest reference scaffold for structure 375 out of 909 .
# [*] Finding closest reference scaffold for structure 376 out of 909 .
# [*] Finding closest reference scaffold for structure 377 out of 909 .
# [*] Finding closest reference scaffold for structure 378 out of 909 .
# [*] Finding closest reference scaffold for structure 379 out of 909 .
# [*] Finding closest reference scaffold for structure 380 out of 909 .
# [*] Finding closest reference scaffold for structure 381 out of 909 .
# [*] Finding closest reference scaffold for structure 382 out of 909 .
# [*] Finding closest reference scaffold for structure 383 out of 909 .
# [*] Finding closest reference scaffold for structure 384 out of 909 .
# [*] Finding closest reference scaffold for structure 385 out of 909 .
# [*] Finding closest reference scaffold for structure 386 out of 909 .
# [*] Finding closest reference scaffold for structure 387 out of 909 .
# [*] Finding closest reference scaffold for structure 388 out of 909 .
# [*] Finding closest reference scaffold for structure 389 out of 909 .
# [*] Finding closest reference scaffold for structure 390 out of 909 .
# [*] Finding closest reference scaffold for structure 391 out of 909 .
# [*] Finding closest reference scaffold for structure 392 out of 909 .
# [*] Finding closest reference scaffold for structure 393 out of 909 .
# [*] Finding closest reference scaffold for structure 394 out of 909 .
# [*] Finding closest reference scaffold for structure 395 out of 909 .
# [*] Finding closest reference scaffold for structure 396 out of 909 .
# [*] Finding closest reference scaffold for structure 397 out of 909 .
# [*] Finding closest reference scaffold for structure 398 out of 909 .
# [*] Finding closest reference scaffold for structure 399 out of 909 .
# [*] Finding closest reference scaffold for structure 400 out of 909 .
# [*] Finding closest reference scaffold for structure 401 out of 909 .
# [*] Finding closest reference scaffold for structure 402 out of 909 .
# [*] Finding closest reference scaffold for structure 403 out of 909 .
# [*] Finding closest reference scaffold for structure 404 out of 909 .
# [*] Finding closest reference scaffold for structure 405 out of 909 .
# [*] Finding closest reference scaffold for structure 406 out of 909 .
# [*] Finding closest reference scaffold for structure 407 out of 909 .
# [*] Finding closest reference scaffold for structure 408 out of 909 .
# [*] Finding closest reference scaffold for structure 409 out of 909 .
# [*] Finding closest reference scaffold for structure 410 out of 909 .
# [*] Finding closest reference scaffold for structure 411 out of 909 .
# [*] Finding closest reference scaffold for structure 412 out of 909 .
# [*] Finding closest reference scaffold for structure 413 out of 909 .
# [*] Finding closest reference scaffold for structure 414 out of 909 .
# [*] Finding closest reference scaffold for structure 415 out of 909 .
# [*] Finding closest reference scaffold for structure 416 out of 909 .
# [*] Finding closest reference scaffold for structure 417 out of 909 .
# [*] Finding closest reference scaffold for structure 418 out of 909 .
# [*] Finding closest reference scaffold for structure 419 out of 909 .
# [*] Finding closest reference scaffold for structure 420 out of 909 .
# [*] Finding closest reference scaffold for structure 421 out of 909 .
# [*] Finding closest reference scaffold for structure 422 out of 909 .
# [*] Finding closest reference scaffold for structure 423 out of 909 .
# [*] Finding closest reference scaffold for structure 424 out of 909 .
# [*] Finding closest reference scaffold for structure 425 out of 909 .
# [*] Finding closest reference scaffold for structure 426 out of 909 .
# [*] Finding closest reference scaffold for structure 427 out of 909 .
# [*] Finding closest reference scaffold for structure 428 out of 909 .
# [*] Finding closest reference scaffold for structure 429 out of 909 .
# [*] Finding closest reference scaffold for structure 430 out of 909 .
# [*] Finding closest reference scaffold for structure 431 out of 909 .
# [*] Finding closest reference scaffold for structure 432 out of 909 .
# [*] Finding closest reference scaffold for structure 433 out of 909 .
# [*] Finding closest reference scaffold for structure 434 out of 909 .
# [*] Finding closest reference scaffold for structure 435 out of 909 .
# [*] Finding closest reference scaffold for structure 436 out of 909 .
# [*] Finding closest reference scaffold for structure 437 out of 909 .
# [*] Finding closest reference scaffold for structure 438 out of 909 .
# [*] Finding closest reference scaffold for structure 439 out of 909 .
# [*] Finding closest reference scaffold for structure 440 out of 909 .
# [*] Finding closest reference scaffold for structure 441 out of 909 .
# [*] Finding closest reference scaffold for structure 442 out of 909 .
# [*] Finding closest reference scaffold for structure 443 out of 909 .
# [*] Finding closest reference scaffold for structure 444 out of 909 .
# [*] Finding closest reference scaffold for structure 445 out of 909 .
# [*] Finding closest reference scaffold for structure 446 out of 909 .
# [*] Finding closest reference scaffold for structure 447 out of 909 .
# [*] Finding closest reference scaffold for structure 448 out of 909 .
# [*] Finding closest reference scaffold for structure 449 out of 909 .
# [*] Finding closest reference scaffold for structure 450 out of 909 .
# [*] Finding closest reference scaffold for structure 451 out of 909 .
# [*] Finding closest reference scaffold for structure 452 out of 909 .
# [*] Finding closest reference scaffold for structure 453 out of 909 .
# [*] Finding closest reference scaffold for structure 454 out of 909 .
# [*] Finding closest reference scaffold for structure 455 out of 909 .
# [*] Finding closest reference scaffold for structure 456 out of 909 .
# [*] Finding closest reference scaffold for structure 457 out of 909 .
# [*] Finding closest reference scaffold for structure 458 out of 909 .
# [*] Finding closest reference scaffold for structure 459 out of 909 .
# [*] Finding closest reference scaffold for structure 460 out of 909 .
# [*] Finding closest reference scaffold for structure 461 out of 909 .
# [*] Finding closest reference scaffold for structure 462 out of 909 .
# [*] Finding closest reference scaffold for structure 463 out of 909 .
# [*] Finding closest reference scaffold for structure 464 out of 909 .
# [*] Finding closest reference scaffold for structure 465 out of 909 .
# [*] Finding closest reference scaffold for structure 466 out of 909 .
# [*] Finding closest reference scaffold for structure 467 out of 909 .
# [*] Finding closest reference scaffold for structure 468 out of 909 .
# [*] Finding closest reference scaffold for structure 469 out of 909 .
# [*] Finding closest reference scaffold for structure 470 out of 909 .
# [*] Finding closest reference scaffold for structure 471 out of 909 .
# [*] Finding closest reference scaffold for structure 472 out of 909 .
# [*] Finding closest reference scaffold for structure 473 out of 909 .
# [*] Finding closest reference scaffold for structure 474 out of 909 .
# [*] Finding closest reference scaffold for structure 475 out of 909 .
# [*] Finding closest reference scaffold for structure 476 out of 909 .
# [*] Finding closest reference scaffold for structure 477 out of 909 .
# [*] Finding closest reference scaffold for structure 478 out of 909 .
# [*] Finding closest reference scaffold for structure 479 out of 909 .
# [*] Finding closest reference scaffold for structure 480 out of 909 .
# [*] Finding closest reference scaffold for structure 481 out of 909 .
# [*] Finding closest reference scaffold for structure 482 out of 909 .
# [*] Finding closest reference scaffold for structure 483 out of 909 .
# [*] Finding closest reference scaffold for structure 484 out of 909 .
# [*] Finding closest reference scaffold for structure 485 out of 909 .
# [*] Finding closest reference scaffold for structure 486 out of 909 .
# [*] Finding closest reference scaffold for structure 487 out of 909 .
# [*] Finding closest reference scaffold for structure 488 out of 909 .
# [*] Finding closest reference scaffold for structure 489 out of 909 .
# [*] Finding closest reference scaffold for structure 490 out of 909 .
# [*] Finding closest reference scaffold for structure 491 out of 909 .
# [*] Finding closest reference scaffold for structure 492 out of 909 .
# [*] Finding closest reference scaffold for structure 493 out of 909 .
# [*] Finding closest reference scaffold for structure 494 out of 909 .
# [*] Finding closest reference scaffold for structure 495 out of 909 .
# [*] Finding closest reference scaffold for structure 496 out of 909 .
# [*] Finding closest reference scaffold for structure 497 out of 909 .
# [*] Finding closest reference scaffold for structure 498 out of 909 .
# [*] Finding closest reference scaffold for structure 499 out of 909 .
# [*] Finding closest reference scaffold for structure 500 out of 909 .
# [*] Finding closest reference scaffold for structure 501 out of 909 .
# [*] Finding closest reference scaffold for structure 502 out of 909 .
# [*] Finding closest reference scaffold for structure 503 out of 909 .
# [*] Finding closest reference scaffold for structure 504 out of 909 .
# [*] Finding closest reference scaffold for structure 505 out of 909 .
# [*] Finding closest reference scaffold for structure 506 out of 909 .
# [*] Finding closest reference scaffold for structure 507 out of 909 .
# [*] Finding closest reference scaffold for structure 508 out of 909 .
# [*] Finding closest reference scaffold for structure 509 out of 909 .
# [*] Finding closest reference scaffold for structure 510 out of 909 .
# [*] Finding closest reference scaffold for structure 511 out of 909 .
# [*] Finding closest reference scaffold for structure 512 out of 909 .
# [*] Finding closest reference scaffold for structure 513 out of 909 .
# [*] Finding closest reference scaffold for structure 514 out of 909 .
# [*] Finding closest reference scaffold for structure 515 out of 909 .
# [*] Finding closest reference scaffold for structure 516 out of 909 .
# [*] Finding closest reference scaffold for structure 517 out of 909 .
# [*] Finding closest reference scaffold for structure 518 out of 909 .
# [*] Finding closest reference scaffold for structure 519 out of 909 .
# [*] Finding closest reference scaffold for structure 520 out of 909 .
# [*] Finding closest reference scaffold for structure 521 out of 909 .
# [*] Finding closest reference scaffold for structure 522 out of 909 .
# [*] Finding closest reference scaffold for structure 523 out of 909 .
# [*] Finding closest reference scaffold for structure 524 out of 909 .
# [*] Finding closest reference scaffold for structure 525 out of 909 .
# [*] Finding closest reference scaffold for structure 526 out of 909 .
# [*] Finding closest reference scaffold for structure 527 out of 909 .
# [*] Finding closest reference scaffold for structure 528 out of 909 .
# [*] Finding closest reference scaffold for structure 529 out of 909 .
# [*] Finding closest reference scaffold for structure 530 out of 909 .
# [*] Finding closest reference scaffold for structure 531 out of 909 .
# [*] Finding closest reference scaffold for structure 532 out of 909 .
# [*] Finding closest reference scaffold for structure 533 out of 909 .
# [*] Finding closest reference scaffold for structure 534 out of 909 .
# [*] Finding closest reference scaffold for structure 535 out of 909 .
# [*] Finding closest reference scaffold for structure 536 out of 909 .
# [*] Finding closest reference scaffold for structure 537 out of 909 .
# [*] Finding closest reference scaffold for structure 538 out of 909 .
# [*] Finding closest reference scaffold for structure 539 out of 909 .
# [*] Finding closest reference scaffold for structure 540 out of 909 .
# [*] Finding closest reference scaffold for structure 541 out of 909 .
# [*] Finding closest reference scaffold for structure 542 out of 909 .
# [*] Finding closest reference scaffold for structure 543 out of 909 .
# [*] Finding closest reference scaffold for structure 544 out of 909 .
# [*] Finding closest reference scaffold for structure 545 out of 909 .
# [*] Finding closest reference scaffold for structure 546 out of 909 .
# [*] Finding closest reference scaffold for structure 547 out of 909 .
# [*] Finding closest reference scaffold for structure 548 out of 909 .
# [*] Finding closest reference scaffold for structure 549 out of 909 .
# [*] Finding closest reference scaffold for structure 550 out of 909 .
# [*] Finding closest reference scaffold for structure 551 out of 909 .
# [*] Finding closest reference scaffold for structure 552 out of 909 .
# [*] Finding closest reference scaffold for structure 553 out of 909 .
# [*] Finding closest reference scaffold for structure 554 out of 909 .
# [*] Finding closest reference scaffold for structure 555 out of 909 .
# [*] Finding closest reference scaffold for structure 556 out of 909 .
# [*] Finding closest reference scaffold for structure 557 out of 909 .
# [*] Finding closest reference scaffold for structure 558 out of 909 .
# [*] Finding closest reference scaffold for structure 559 out of 909 .
# [*] Finding closest reference scaffold for structure 560 out of 909 .
# ...
# [*] Finding closest reference scaffold for structure 695 out of 909 .
# [*] Finding closest reference scaffold for structure 696 out of 909 .
# [*] Finding closest reference scaffold for structure 697 out of 909 .
# [*] Finding closest reference scaffold for structure 698 out of 909 .
# [*] Finding closest reference scaffold for structure 699 out of 909 .
# [*] Finding closest reference scaffold for structure 700 out of 909 .
# [*] Finding closest reference scaffold for structure 701 out of 909 .
# [*] Finding closest reference scaffold for structure 702 out of 909 .
# [*] Finding closest reference scaffold for structure 703 out of 909 .
# [*] Finding closest reference scaffold for structure 704 out of 909 .
# [*] Finding closest reference scaffold for structure 705 out of 909 .
# [*] Finding closest reference scaffold for structure 706 out of 909 .
# [*] Finding closest reference scaffold for structure 707 out of 909 .
# [*] Finding closest reference scaffold for structure 708 out of 909 .
# [*] Finding closest reference scaffold for structure 709 out of 909 .
# [*] Finding closest reference scaffold for structure 710 out of 909 .
# [*] Finding closest reference scaffold for structure 711 out of 909 .
# [*] Finding closest reference scaffold for structure 712 out of 909 .
# [*] Finding closest reference scaffold for structure 713 out of 909 .
# [*] Finding closest reference scaffold for structure 714 out of 909 .
# [*] Finding closest reference scaffold for structure 715 out of 909 .
# [*] Finding closest reference scaffold for structure 716 out of 909 .
# [*] Finding closest reference scaffold for structure 717 out of 909 .
# [*] Finding closest reference scaffold for structure 718 out of 909 .
# [*] Finding closest reference scaffold for structure 719 out of 909 .
# [*] Finding closest reference scaffold for structure 720 out of 909 .
# [*] Finding closest reference scaffold for structure 721 out of 909 .
# [*] Finding closest reference scaffold for structure 722 out of 909 .
# [*] Finding closest reference scaffold for structure 723 out of 909 .
# [*] Finding closest reference scaffold for structure 724 out of 909 .
# [*] Finding closest reference scaffold for structure 725 out of 909 .
# [*] Finding closest reference scaffold for structure 726 out of 909 .
# [*] Finding closest reference scaffold for structure 727 out of 909 .
# [*] Finding closest reference scaffold for structure 728 out of 909 .
# [*] Finding closest reference scaffold for structure 729 out of 909 .
# [*] Finding closest reference scaffold for structure 730 out of 909 .
# [*] Finding closest reference scaffold for structure 731 out of 909 .
# [*] Finding closest reference scaffold for structure 732 out of 909 .
# [*] Finding closest reference scaffold for structure 733 out of 909 .
# [*] Finding closest reference scaffold for structure 734 out of 909 .
# [*] Finding closest reference scaffold for structure 735 out of 909 .
# [*] Finding closest reference scaffold for structure 736 out of 909 .
# [*] Finding closest reference scaffold for structure 737 out of 909 .
# [*] Finding closest reference scaffold for structure 738 out of 909 .
# [*] Finding closest reference scaffold for structure 739 out of 909 .
# [*] Finding closest reference scaffold for structure 740 out of 909 .
# [*] Finding closest reference scaffold for structure 741 out of 909 .
# [*] Finding closest reference scaffold for structure 742 out of 909 .
# [*] Finding closest reference scaffold for structure 743 out of 909 .
# [*] Finding closest reference scaffold for structure 744 out of 909 .
# [*] Finding closest reference scaffold for structure 745 out of 909 .
# [*] Finding closest reference scaffold for structure 746 out of 909 .
# [*] Finding closest reference scaffold for structure 747 out of 909 .
# [*] Finding closest reference scaffold for structure 748 out of 909 .
# [*] Finding closest reference scaffold for structure 749 out of 909 .
# [*] Finding closest reference scaffold for structure 750 out of 909 .
# [*] Finding closest reference scaffold for structure 751 out of 909 .
# [*] Finding closest reference scaffold for structure 752 out of 909 .
# [*] Finding closest reference scaffold for structure 753 out of 909 .
# [*] Finding closest reference scaffold for structure 754 out of 909 .
# [*] Finding closest reference scaffold for structure 755 out of 909 .
# [*] Finding closest reference scaffold for structure 756 out of 909 .
# [*] Finding closest reference scaffold for structure 757 out of 909 .
# [*] Finding closest reference scaffold for structure 758 out of 909 .
# [*] Finding closest reference scaffold for structure 759 out of 909 .
# [*] Finding closest reference scaffold for structure 760 out of 909 .
# [*] Finding closest reference scaffold for structure 761 out of 909 .
# [*] Finding closest reference scaffold for structure 762 out of 909 .
# [*] Finding closest reference scaffold for structure 763 out of 909 .
# [*] Finding closest reference scaffold for structure 764 out of 909 .
# [*] Finding closest reference scaffold for structure 765 out of 909 .
# [*] Finding closest reference scaffold for structure 766 out of 909 .
# [*] Finding closest reference scaffold for structure 767 out of 909 .
# [*] Finding closest reference scaffold for structure 768 out of 909 .
# [*] Finding closest reference scaffold for structure 769 out of 909 .
# [*] Finding closest reference scaffold for structure 770 out of 909 .
# [*] Finding closest reference scaffold for structure 771 out of 909 .
# [*] Finding closest reference scaffold for structure 772 out of 909 .
# [*] Finding closest reference scaffold for structure 773 out of 909 .
# [*] Finding closest reference scaffold for structure 774 out of 909 .
# [*] Finding closest reference scaffold for structure 775 out of 909 .
# [*] Finding closest reference scaffold for structure 776 out of 909 .
# [*] Finding closest reference scaffold for structure 777 out of 909 .
# [*] Finding closest reference scaffold for structure 778 out of 909 .
# [*] Finding closest reference scaffold for structure 779 out of 909 .
# [*] Finding closest reference scaffold for structure 780 out of 909 .
# [*] Finding closest reference scaffold for structure 781 out of 909 .
# [*] Finding closest reference scaffold for structure 782 out of 909 .
# [*] Finding closest reference scaffold for structure 783 out of 909 .
# [*] Finding closest reference scaffold for structure 784 out of 909 .
# [*] Finding closest reference scaffold for structure 785 out of 909 .
# [*] Finding closest reference scaffold for structure 786 out of 909 .
# [*] Finding closest reference scaffold for structure 787 out of 909 .
# [*] Finding closest reference scaffold for structure 788 out of 909 .
# [*] Finding closest reference scaffold for structure 789 out of 909 .
# [*] Finding closest reference scaffold for structure 790 out of 909 .
# [*] Finding closest reference scaffold for structure 791 out of 909 .
# [*] Finding closest reference scaffold for structure 792 out of 909 .
# [*] Finding closest reference scaffold for structure 793 out of 909 .
# [*] Finding closest reference scaffold for structure 794 out of 909 .
# [*] Finding closest reference scaffold for structure 795 out of 909 .
# [*] Finding closest reference scaffold for structure 796 out of 909 .
# [*] Finding closest reference scaffold for structure 797 out of 909 .
# [*] Finding closest reference scaffold for structure 798 out of 909 .
# [*] Finding closest reference scaffold for structure 799 out of 909 .
# [*] Finding closest reference scaffold for structure 800 out of 909 .
# [*] Finding closest reference scaffold for structure 801 out of 909 .
# [*] Finding closest reference scaffold for structure 802 out of 909 .
# [*] Finding closest reference scaffold for structure 803 out of 909 .
# [*] Finding closest reference scaffold for structure 804 out of 909 .
# [*] Finding closest reference scaffold for structure 805 out of 909 .
# [*] Finding closest reference scaffold for structure 806 out of 909 .
# [*] Finding closest reference scaffold for structure 807 out of 909 .
# [*] Finding closest reference scaffold for structure 808 out of 909 .
# [*] Finding closest reference scaffold for structure 809 out of 909 .
# [*] Finding closest reference scaffold for structure 810 out of 909 .
# [*] Finding closest reference scaffold for structure 811 out of 909 .
# [*] Finding closest reference scaffold for structure 812 out of 909 .
# [*] Finding closest reference scaffold for structure 813 out of 909 .
# [*] Finding closest reference scaffold for structure 814 out of 909 .
# [*] Finding closest reference scaffold for structure 815 out of 909 .
# [*] Finding closest reference scaffold for structure 816 out of 909 .
# [*] Finding closest reference scaffold for structure 817 out of 909 .
# [*] Finding closest reference scaffold for structure 818 out of 909 .
# [*] Finding closest reference scaffold for structure 819 out of 909 .
# [*] Finding closest reference scaffold for structure 820 out of 909 .
# [*] Finding closest reference scaffold for structure 821 out of 909 .
# [*] Finding closest reference scaffold for structure 822 out of 909 .
# [*] Finding closest reference scaffold for structure 823 out of 909 .
# [*] Finding closest reference scaffold for structure 824 out of 909 .
# [*] Finding closest reference scaffold for structure 825 out of 909 .
# [*] Finding closest reference scaffold for structure 826 out of 909 .
# [*] Finding closest reference scaffold for structure 827 out of 909 .
# [*] Finding closest reference scaffold for structure 828 out of 909 .
# [*] Finding closest reference scaffold for structure 829 out of 909 .
# [*] Finding closest reference scaffold for structure 830 out of 909 .
# [*] Finding closest reference scaffold for structure 831 out of 909 .
# [*] Finding closest reference scaffold for structure 832 out of 909 .
# [*] Finding closest reference scaffold for structure 833 out of 909 .
# [*] Finding closest reference scaffold for structure 834 out of 909 .
# [*] Finding closest reference scaffold for structure 835 out of 909 .
# [*] Finding closest reference scaffold for structure 836 out of 909 .
# [*] Finding closest reference scaffold for structure 837 out of 909 .
# [*] Finding closest reference scaffold for structure 838 out of 909 .
# [*] Finding closest reference scaffold for structure 839 out of 909 .
# [*] Finding closest reference scaffold for structure 840 out of 909 .
# [*] Finding closest reference scaffold for structure 841 out of 909 .
# [*] Finding closest reference scaffold for structure 842 out of 909 .
# [*] Finding closest reference scaffold for structure 843 out of 909 .
# [*] Finding closest reference scaffold for structure 844 out of 909 .
# [*] Finding closest reference scaffold for structure 845 out of 909 .
# [*] Finding closest reference scaffold for structure 846 out of 909 .
# [*] Finding closest reference scaffold for structure 847 out of 909 .
# [*] Finding closest reference scaffold for structure 848 out of 909 .
# [*] Finding closest reference scaffold for structure 849 out of 909 .
# [*] Finding closest reference scaffold for structure 850 out of 909 .
# [*] Finding closest reference scaffold for structure 851 out of 909 .
# [*] Finding closest reference scaffold for structure 852 out of 909 .
# [*] Finding closest reference scaffold for structure 853 out of 909 .
# [*] Finding closest reference scaffold for structure 854 out of 909 .
# [*] Finding closest reference scaffold for structure 855 out of 909 .
# [*] Finding closest reference scaffold for structure 856 out of 909 .
# [*] Finding closest reference scaffold for structure 857 out of 909 .
# [*] Finding closest reference scaffold for structure 858 out of 909 .
# [*] Finding closest reference scaffold for structure 859 out of 909 .
# [*] Finding closest reference scaffold for structure 860 out of 909 .
# [*] Finding closest reference scaffold for structure 861 out of 909 .
# [*] Finding closest reference scaffold for structure 862 out of 909 .
# [*] Finding closest reference scaffold for structure 863 out of 909 .
# [*] Finding closest reference scaffold for structure 864 out of 909 .
# [*] Finding closest reference scaffold for structure 865 out of 909 .
# [*] Finding closest reference scaffold for structure 866 out of 909 .
# [*] Finding closest reference scaffold for structure 867 out of 909 .
# [*] Finding closest reference scaffold for structure 868 out of 909 .
# [*] Finding closest reference scaffold for structure 869 out of 909 .
# [*] Finding closest reference scaffold for structure 870 out of 909 .
# [*] Finding closest reference scaffold for structure 871 out of 909 .
# [*] Finding closest reference scaffold for structure 872 out of 909 .
# [*] Finding closest reference scaffold for structure 873 out of 909 .
# [*] Finding closest reference scaffold for structure 874 out of 909 .
# [*] Finding closest reference scaffold for structure 875 out of 909 .
# [*] Finding closest reference scaffold for structure 876 out of 909 .
# [*] Finding closest reference scaffold for structure 877 out of 909 .
# [*] Finding closest reference scaffold for structure 878 out of 909 .
# [*] Finding closest reference scaffold for structure 879 out of 909 .
# [*] Finding closest reference scaffold for structure 880 out of 909 .
# [*] Finding closest reference scaffold for structure 881 out of 909 .
# [*] Finding closest reference scaffold for structure 882 out of 909 .
# [*] Finding closest reference scaffold for structure 883 out of 909 .
# [*] Finding closest reference scaffold for structure 884 out of 909 .
# [*] Finding closest reference scaffold for structure 885 out of 909 .
# [*] Finding closest reference scaffold for structure 886 out of 909 .
# [*] Finding closest reference scaffold for structure 887 out of 909 .
# [*] Finding closest reference scaffold for structure 888 out of 909 .
# [*] Finding closest reference scaffold for structure 889 out of 909 .
# [*] Finding closest reference scaffold for structure 890 out of 909 .
# [*] Finding closest reference scaffold for structure 891 out of 909 .
# [*] Finding closest reference scaffold for structure 892 out of 909 .
# [*] Finding closest reference scaffold for structure 893 out of 909 .
# [*] Finding closest reference scaffold for structure 894 out of 909 .
# [*] Finding closest reference scaffold for structure 895 out of 909 .
# [*] Finding closest reference scaffold for structure 896 out of 909 .
# [*] Finding closest reference scaffold for structure 897 out of 909 .
# [*] Finding closest reference scaffold for structure 898 out of 909 .
# [*] Finding closest reference scaffold for structure 899 out of 909 .
# [*] Finding closest reference scaffold for structure 900 out of 909 .
# [*] Finding closest reference scaffold for structure 901 out of 909 .
# [*] Finding closest reference scaffold for structure 902 out of 909 .
# [*] Finding closest reference scaffold for structure 903 out of 909 .
# [*] Finding closest reference scaffold for structure 904 out of 909 .
# [*] Finding closest reference scaffold for structure 905 out of 909 .
# [*] Finding closest reference scaffold for structure 906 out of 909 .
# [*] Finding closest reference scaffold for structure 907 out of 909 .
# [*] Finding closest reference scaffold for structure 908 out of 909 .
# [*] Finding closest reference scaffold for structure 909 out of 909 .
# Generating HCASE embedding at parameter z (PHC order): 2, nr_scaffolds: 55597, bucket_nr: 16,  bucket_size 3706.466667 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 3, nr_scaffolds: 55597, bucket_nr: 64,  bucket_size 882.492063 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 4, nr_scaffolds: 55597, bucket_nr: 256,  bucket_size 218.027451 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 5, nr_scaffolds: 55597, bucket_nr: 1024,  bucket_size 54.347019 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 6, nr_scaffolds: 55597, bucket_nr: 4096,  bucket_size 13.576801 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 7, nr_scaffolds: 55597, bucket_nr: 16384,  bucket_size 3.393579 ..
# .. done.
# Generating HCASE embedding at parameter z (PHC order): 8, nr_scaffolds: 55597, bucket_nr: 65536,  bucket_size 0.848356 ..
# .. done.

# %%
df_embedded.to_csv (fname_out_embedding, sep = '\t', index = False)

# %%
# Plot results


df_emb = df_embedded

adf_2 = df_emb[df_emb['hc_order'] == 2].copy()
adf_3 = df_emb[df_emb['hc_order'] == 3].copy()
adf_4 = df_emb[df_emb['hc_order'] == 4].copy()
adf_5 = df_emb[df_emb['hc_order'] == 5].copy()
adf_6 = df_emb[df_emb['hc_order'] == 6].copy()
adf_7 = df_emb[df_emb['hc_order'] == 7].copy()
adf_8 = df_emb[df_emb['hc_order'] == 8].copy()





df_2_color = color_scaffolds(adf_2, df_structures)
df_3_color = color_scaffolds(adf_3, df_structures)
df_4_color = color_scaffolds(adf_4, df_structures)
df_5_color = color_scaffolds(adf_5, df_structures)
df_6_color = color_scaffolds(adf_6, df_structures)
df_7_color = color_scaffolds(adf_7, df_structures)
df_8_color = color_scaffolds(adf_8, df_structures)



fig = plt.figure()

fig, subfigures = plt.subplots(nrows = 4, ncols = 2, figsize = (15, 22))

panel_plot_multi_scaffolds (subfigures[0][0], df_2_color, subfig_label = 'z = ', z = 2)
panel_plot_multi_scaffolds (subfigures[0][1], df_3_color, subfig_label = 'z = ', z = 3)
panel_plot_multi_scaffolds (subfigures[1][0], df_4_color, subfig_label = 'z = ', z = 4)
panel_plot_multi_scaffolds (subfigures[1][1], df_5_color, subfig_label = 'z = ', z = 5)
panel_plot_multi_scaffolds (subfigures[2][0], df_6_color, subfig_label = 'z = ', z = 6)
panel_plot_multi_scaffolds (subfigures[2][1], df_7_color, subfig_label = 'z = ', z = 7)
panel_plot_multi_scaffolds (subfigures[3][0], df_8_color, subfig_label = 'z = ', z = 8)

subfigures[3][1].axis('off')

subfigures[0][0].text(-0.25, 1.25, "A", transform=subfigures[0][0].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[0][1].text(-0.25, 1.25, "B", transform=subfigures[0][1].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[1][0].text(-0.25, 1.25, "C", transform=subfigures[1][0].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[1][1].text(-0.25, 1.25, "D", transform=subfigures[1][1].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[2][0].text(-0.25, 1.25, "E", transform=subfigures[2][0].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[2][1].text(-0.25, 1.25, "F", transform=subfigures[2][1].transAxes,
            fontsize=64, fontweight='bold', va='top')
subfigures[3][0].text(-0.25, 1.25, "G", transform=subfigures[3][0].transAxes,
            fontsize=64, fontweight='bold', va='top')

fig.suptitle('Cherry Picked Scaffolds Embedded in HCASE ChEMBL Space', fontsize = 32, y = 1.02)
#fig.supylabel('Dim 2')


plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.5)

plt.savefig (fname_out_cp_scaffold_hcase_embedding_plot, dpi=300)

plt.show()







df_2_color['phc_order'] = 2
df_3_color['phc_order'] = 3
df_4_color['phc_order'] = 4
df_5_color['phc_order'] = 5
df_6_color['phc_order'] = 6
df_7_color['phc_order'] = 7
df_8_color['phc_order'] = 8


df_coords = df_2_color.append(df_3_color, ignore_index = True)
df_coords = df_coords.append(df_4_color, ignore_index = True)
df_coords = df_coords.append(df_5_color, ignore_index = True)
df_coords = df_coords.append(df_6_color, ignore_index = True)
df_coords = df_coords.append(df_7_color, ignore_index = True)
df_coords = df_coords.append(df_8_color, ignore_index = True)

df_coords.to_csv (fname_out_colored_embedding, sep = '\t', index = False)

# %%
# References:

# Ref: https://github.com/matplotlib/matplotlib/issues/3466/
# Ref: https://htmlcolorcodes.com/color-picker/
# Ref: https://iwatobipen.wordpress.com/2017/11/03/draw-high-quality-molecular-image-in-rdkit-rdkit/
# Ref: https://matplotlib.org/3.1.0/gallery/subplots_axes_and_figures/subplots_demo.html
# Ref: https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
# Ref: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
# Ref: https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.title.html
# Ref: https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers
# Ref: https://matplotlib.org/3.1.1/gallery/shapes_and_collections/scatter.html
# Ref: https://matplotlib.org/3.1.1/tutorials/colors/colors.html
# Ref: https://python-graph-gallery.com/106-seaborn-style-on-matplotlib-plot/
# Ref: https://python-graph-gallery.com/122-multiple-lines-chart/
# Ref: https://python-graph-gallery.com/125-small-multiples-for-line-chart/
# Ref: https://python-graph-gallery.com/197-available-color-palettes-with-matplotlib/
# Ref: https://seaborn.pydata.org/examples/many_facets.html
# Ref: https://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point
# Ref: https://stackoverflow.com/questions/14827650/pyplot-scatter-plot-marker-size
# Ref: https://stackoverflow.com/questions/17682216/scatter-plot-and-color-mapping-in-python
# Ref: https://stackoverflow.com/questions/31686530/matplotlib-generate-a-new-graph-in-a-new-window-for-subsequent-program-runs/31686783
# Ref: https://stackoverflow.com/questions/39870642/matplotlib-how-to-plot-a-high-resolution-graph
# Ref: https://stackoverflow.com/questions/57568311/matplotlib-scatter-issue-with-python-3-x
# Ref: https://www.nceas.ucsb.edu/~frazier/RSpatialGuides/colorPaletteCheatsheet.pdf
# Ref: https://www.pluralsight.com/guides/choosing-color-palettes
# Ref: https://www.rdkit.org/docs/GettingStartedInPython.html
# Ref: https://www.rdkit.org/docs/source/rdkit.Chem.Draw.html
# Ref: https://www.science-emergence.com/Articles/How-to-create-a-scatter-plot-with-several-colors-in-matplotlib-/
# Ref: ChatGPT 4.0 by OpenAI [https://chat.openai.com]
